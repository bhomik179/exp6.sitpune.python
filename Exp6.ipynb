# %%
#Bhomik V Keshi 25070123172

#Experiment No :- 6
#Aim :- Study of conditional statement in python

# %%
# a) Check whether a number is positive or negative
# b) Check whether a number is positive, negative, or zero

num = int(input("Enter a number: "))

if num > 0:
    print("positive")
elif num < 0:
    print("negative")
else:
    print("zero")
# Out:
# Enter a number: 56
# positive

# %%
# Check whether a number is even or odd

num = int(input("Enter a number: "))

if num % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# Enter a number: 54
# even

# %%
# To check whether a number is greater or not

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

if num1 > num2:
    print("Largest:", num1)
else:
    print("Largest:", num2)
# Out:
# Enter first number: 1
# Enter second number: 17
# Largest: 17

# %%
# Program to input 3 numbers and find the largest one

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest number is:", a)
elif b >= a and b >= c:
    print("Largest number is:", b)
else:
    print("Largest number is:", c)
# Out:
# Enter first number: 57
# Enter second number: 38
# Enter third number: 9237
# Largest number is: 9237

# %%
# 5.Get input for 5 subjects in one line and find the average
# Calculate grade using if-elif-else

marks = list(map(int, input("Enter marks of 5 subjects: ").split()))

total = sum(marks)
average = total / 5

print("Average marks:", average)

if average >= 90:
    print("Grade: A")
elif average >= 75:
    print("Grade: B")
elif average >= 60:
    print("Grade: C")
elif average >= 40:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Enter marks of 5 subjects: 56
# Average marks: 11.2
# Grade: F

# %%
# Activity 6.5
# Get input from user for 3 subjects and find average.
# Calculate the grade using if-elif-else.

x = int(input("Enter marks of 1 subject: "))
y = int(input("Enter marks of 2 subject: "))
z = int(input("Enter marks of 3 subject: "))

# Calculate average manually: (sum) / (count)
a = (x + y + z) / 3
print("Average:", a)

if a >= 90:
    print("Grade: A")
elif a >= 75:
    print("Grade: B")
elif a >= 60:
    print("Grade: C")
elif a >= 40:
    print("Grade: D")
else:
    print("Grade: F")9
# Out:
# Enter marks of 1 subject: 98
# Enter marks of 2 subject: 78
# Enter marks of 3 subject: 9
# Average: 61.666666666666664
# Grade: C

# %%
# 6. Check whether a year is a leap year

year = int(input("Enter year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year: 1900
# Not a Leap Year

# %%
# Program to increment a given date by one day


# Taking input from the user
day = int(input("Enter day: "))
month = int(input("Enter month: "))
year = int(input("Enter year: "))

# Variable to store number of days in the month
days_in_month = 0

# Checking month to assign correct number of days
if month == 1:
    days_in_month = 31

elif month == 2:
    # Checking for leap year
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        days_in_month = 29
    else:
        days_in_month = 28

elif month == 3:
    days_in_month = 31

elif month == 4:
    days_in_month = 30

elif month == 5:
    days_in_month = 31

elif month == 6:
    days_in_month = 30

elif month == 7:
    days_in_month = 31

elif month == 8:
    days_in_month = 31

elif month == 9:
    days_in_month = 30

elif month == 10:
    days_in_month = 31

elif month == 11:
    days_in_month = 30

elif month == 12:
    days_in_month = 31


# Incrementing the date
if day < days_in_month:
    day = day + 1

else:
    day = 1
    if month < 12:
        month = month + 1
    else:
        month = 1
        year = year + 1


# Displaying the incremented date
print("Incremented Date is:")
print("Day:", day)
print("Month:", month)
print("Year:", year)
# Out:
# Enter day: 14
# Enter month: 2
# Enter year: 2025
# Incremented Date is:
# Day: 15
# Month: 2
# Year: 2025
